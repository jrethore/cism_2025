# %% [markdown]
# # Finite Element Simulation from DIC measurements
# - FE-DIC using a mesh of triangular elements
# - pick up the modal displacement at the top and bottom edges
# - replace 2D triangular elements by 1D bar elements for the sake of simplicity
# - use a given elastic non-linear constitutive law

# %%
# Import Libraries
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.collections import LineCollection
import scipy
from scipy import ndimage
from scipy.sparse import csr_matrix as smatrix
import scipy.sparse.linalg as splinalg
import os
import sys
sources = os.path.join(os.pardir, "modules")
if sources not in sys.path:
    sys.path.insert(0, sources)
import fem

# %%
Ns=10
inp='dic-coarse.res'
pix2m=25.e-6; # pixel to m conversion
thickness=3e-3 # speimen thicness in m
dL=100
young=2.e8*pix2m;
n=0.2

(X,conn)=fem.readDICmesh(inp)
model=fem.FEModel()

model.X=X
model.conn=conn
model.Assemble()
W=model.W
B=model.B
Xg=0.5*(X[conn[:,0]]+X[conn[:,1]])
Nnodes=X.shape[0]
Nelems=conn.shape[0]
fig, ax = plt.subplots()
model.show_mesh(fig, ax)

# %%
top=X[:,1]>max(X[:,1])*0.99
bot=X[:,1]<max(X[:,1])*0.01

nodes_index=np.arange(Nnodes)
top_nodes=nodes_index[top]
ntop=top_nodes.size
free=np.logical_not(np.logical_or(top, bot))
free_nodes=nodes_index[free]
nfree=free_nodes.size
free_ddls=np.r_[free_nodes,free_nodes+Nnodes]


fig, ax = plt.subplots()
model.show_mesh(fig, ax)
plt.plot(X[top,0],X[top,1].T,'ro');
plt.plot(X[bot,0],X[bot,1].T,'ro');

# %%
Fext=np.zeros(2*Nnodes)
Uimp=np.zeros(2*Nnodes)
Uimp[top_nodes+Nnodes]=1
U=np.zeros(2*Nnodes)
L=max(X[:,1])-min(X[:,1])

dS=young/n
K=(B.T)*(W*B*dS)        

# kg.m.s^-2/m^2=kg.s^-2/m

dU=np.zeros(2*Nnodes)
E=B.dot(U)
lfs=np.arange(1/Ns,1+1/Ns,1/Ns)
itmax=100
crit=1.e-6
for lf in lfs:
    print(lf*dL)
    U[top_nodes+Nnodes]=dL*lf
    iter=0
    ndU=1
    while (ndU > crit)&(iter<itmax):
        E=B.dot(U)
        S=young*(1-np.exp(-np.abs(E)/n))*np.sign(E)
        Fint=(B.T).dot(W.dot(S))
        Res=Fext-Fint
        dU[free_ddls]=splinalg.spsolve(K[np.ix_(free_ddls,free_ddls)],Res[free_ddls])
        U+=dU
        iter+=1
        ndU=np.linalg.norm(dU)/np.linalg.norm(U)
        #print(ndU)
    print('For load factor ',lf,' after ',iter,'iterations', 'dU/U=',ndU)
# Out:
# 10.0
# For load factor  0.1  after  6 iterations dU/U= 2.0184789965126246e-07
# 20.0
# For load factor  0.2  after  6 iterations dU/U= 8.736081860820997e-07
# 30.000000000000004
# For load factor  0.30000000000000004  after  7 iterations dU/U= 1.311741377174835e-07
# 40.0
# For load factor  0.4  after  7 iterations dU/U= 3.4591745958641045e-07
# 50.0
# For load factor  0.5  after  7 iterations dU/U= 7.414917503746439e-07
# 60.0
# For load factor  0.6  after  8 iterations dU/U= 1.675886483762707e-07
# 70.0
# For load factor  0.7000000000000001  after  8 iterations dU/U= 3.2969350581417674e-07
# 80.0
# For load factor  0.8  after  8 iterations dU/U= 5.908552701168054e-07
# 90.0
# For load factor  0.9  after  8 iterations dU/U= 9.849791951065984e-07
# 100.0
# For load factor  1.0  after  9 iterations dU/U= 3.204180809129442e-07

# %%
Fres=sum(Fint[top_nodes+Nnodes])*thickness
print(Fres)
# Out:
# 52.67306774596354

# %%
np.savez('fem-from-dic',U=U,Fres=Fres,Sref=S/pix2m)

# %%
fig, ax = plt.subplots()
model.show_field(fig, ax,U[Nnodes::], name = "U")
# Out:
# (<matplotlib.collections.LineCollection at 0x7ca0957215e0>,
#  <matplotlib.colorbar.Colorbar at 0x7ca095b99c70>)

# %%
fig, ax = plt.subplots()
model.show_field(fig, ax,E, name = "E")
# Out:
# (<matplotlib.collections.LineCollection at 0x7ca095822c60>,
#  <matplotlib.colorbar.Colorbar at 0x7ca0967afb30>)
